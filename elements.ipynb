# %% [markdown]
# <a href="https://colab.research.google.com/github/tomek123z/Gradient-descent/blob/main/elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def guidata (hObject, handles):
 print(handles.b1) 
hObject= input("Enter hObject:")
value= input("handles.contador is: ")
i = input("i : ")
print(f"handles.b{i} of handles.contador == {value}  is: {%d}")
def get(hObject,  value):
  return value
def errordlg (mes,bug):
 print(bug + " " + mes)
def Be_Callback(hObject = None,eventdata = None,handles = None): 
    # hObject    handle to Be (see GCBO)
# eventdata  reserved - to be defined in t12 future version of MATLAB
# handles    structure with handles and user data (see GUIDATA)
    die = get(hObject,'Value')

    handles.die = die
    if handles.sis == 1:
        if handles.die == 1:
            set(hObject,'Backgroundcolor',handles.preslitio)
            if handles.contador == 2:
                set(handles.Be,'Value',0)
                errordlg('Must select two elements','Error')
                set(hObject,'Backgroundcolor',handles.unpreslitio)
            else:
                if handles.contador == 1:
                
                    handles.b1 = 'Be'
                    handles.b2 = 4.9
                    handles.b3 = 5.05
                    handles.b4 = 4.66
                    handles.b5 = 100400000000.0
                    handles.b6 = 143200000000.0
                    handles.b7 = 1
                    handles.b8 = 0.4
                    handles.Aw2 = 9.01218
                    handles.gam2 = 1390
                    handles.b9 = 1560
                    set(handles.t5,'String',handles.b1)
                    handles.contador = handles.contador + 1
                else:
                    if handles.contador == 0:
                        handles.a1 = 'Be'
                        handles.a2 = 4.9
                        handles.a3 = 5.05
                        handles.a4 = 4.66
                        handles.a5 = 100400000000.0
                        handles.a6 = 143200000000.0
                        handles.a7 = 1
                        handles.a8 = 0.4
                        handles.Aw1 = 9.01218
                        handles.gam1 = 1390
                        handles.a9 = 1560
                        set(handles.t4,'String',handles.a1)
                        handles.contador = handles.contador + 1
                    else:
                        if handles.contador == 3:
                            set(handles.Be,'Value',0)
                            set(hObject,'Backgroundcolor',handles.unpreslitio)
                            handles.contador = 2
        else:
            set(hObject,'Backgroundcolor',handles.unpreslitio)
            if handles.a1 == 'Be':
                handles.a1 = handles.b1
                handles.a2 = handles.b2
                handles.a3 = handles.b3
                handles.a4 = handles.b4
                handles.a5 = handles.b5
                handles.a6 = handles.b6
                handles.a7 = handles.b7
                handles.a8 = handles.b8
                handles.Aw1 = handles.Aw2
                handles.gam1 = handles.gam2
                handles.a9 = handles.b9
                set(handles.t4,'String',handles.b1)
                handles.b1 = handles.d1
                handles.b2 = handles.d2
                handles.b3 = handles.d3
                handles.b4 = handles.d4
                handles.b5 = handles.d5
                handles.b6 = handles.d6
                handles.b7 = handles.d7
                handles.b8 = handles.d8
                handles.Aw2 = handles.Aw3
                handles.gam2 = handles.gam3
                handles.b9 = handles.d9
                set(handles.t5,'String',handles.d1)
                handles.d1 = ' '
                handles.d2 = 0
                handles.d3 = 0
                handles.d4 = 0
                handles.d5 = 0
                handles.d6 = 0
                handles.d7 = 0
                handles.d8 = 0
                handles.Aw3 = 0
                handles.gam3 = 0
                handles.d9 = 0
                set(handles.t6,'String',' ')
                handles.contador = handles.contador - 1
            else:
                if handles.b1 == 'Be':
                    handles.b1 = handles.d1
                    handles.b2 = handles.d2
                    handles.b3 = handles.d3
                    handles.b4 = handles.d4
                    handles.b5 = handles.d5
                    handles.b6 = handles.d6
                    handles.b7 = handles.d7
                    handles.b8 = handles.d8
                    handles.Aw2 = handles.Aw3
                    handles.gam2 = handles.gam3
                    handles.b9 = handles.d9
                    set(handles.t5,'String',handles.d1)
                    handles.d1 = ' '
                    handles.d2 = 0
                    handles.d3 = 0
                    handles.d4 = 0
                    handles.d5 = 0
                    handles.d6 = 0
                    handles.d7 = 0
                    handles.d8 = 0
                    handles.Aw3 = 0
                    handles.gam3 = 0
                    handles.d9 = 0
                    set(handles.t6,'String',' ')
                    handles.contador = handles.contador - 1
                else:
                    if handles.d1 == 'Be':
                        handles.d1 = ' '
                        handles.d2 = 0
                        handles.d3 = 0
                        handles.d4 = 0
                        handles.d5 = 0
                        handles.d6 = 0
                        handles.d7 = 0
                        handles.d8 = 0
                        handles.Aw3 = 0
                        handles.gam3 = 0
                        handles.d9 = 0
                        set(handles.t6,'String',' ')
                        handles.contador = handles.contador - 1
    else:
        if handles.die == 1:
            set(hObject,'Backgroundcolor',handles.preslitio)
            if handles.contador == 3:
                set(handles.Be,'Value',0)
                errordlg('Must select two elements','Error')
                set(hObject,'Backgroundcolor',handles.unpreslitio)
            else:
                if handles.contador == 2:
                    handles.d1 = 'Be'
                    handles.d2 = 4.9
                    handles.d3 = 5.05
                    handles.d4 = 4.66
                    handles.d5 = 100400000000.0
                    handles.d6 = 143200000000.0
                    handles.d7 = 1
                    handles.d8 = 0
                    handles.Aw3 = 6.941
                    handles.gam3 = 398
                    handles.d9 = 453.69
                    set(handles.t6,'String',handles.d1)
                    handles.contador = handles.contador + 1
                else:
                    if handles.contador == 1:
                        handles.b1 = 'Be'
                        handles.b2 = 4.9
                        handles.b3 = 5.05
                        handles.b4 = 4.66
                        handles.b5 = 100400000000.0
                        handles.b6 = 143200000000.0
                        handles.b7 = 1
                        handles.b8 = 0
                        handles.Aw2 = 6.941
                        handles.gam2 = 398
                        handles.b9 = 453.69
                        set(handles.t5,'String',handles.b1)
                        handles.contador = handles.contador + 1
                    else:
                        if handles.contador == 0:
                            handles.a1 = 'Be'
                            handles.a2 = 4.9
                            handles.a3 = 5.05
                            handles.a4 = 4.66
                            handles.a5 = 100400000000.0
                            handles.a6 = 143200000000.0
                            handles.a7 = 1
                            handles.a8 = 0
                            handles.Aw1 = 6.941
                            handles.gam1 = 398
                            handles.a9 = 453.69
                            set(handles.t4,'String',handles.a1)
                            handles.contador = handles.contador + 1
                        else:
                            if handles.contador == 4:
                                handles.contador = 0
        else:
            set(hObject,'Backgroundcolor',handles.unpreslitio)
            if handles.a1 == 'Be':
                handles.a1 = handles.b1
                handles.a2 = handles.b2
                handles.a3 = handles.b3
                handles.a4 = handles.b4
                handles.a5 = handles.b5
                handles.a6 = handles.b6
                handles.a7 = handles.b7
                handles.a8 = handles.b8
                handles.Aw1 = handles.Aw2
                handles.gam1 = handles.gam2
                handles.a9 = handles.b9
                handles.b1 = handles.d1
                handles.b2 = handles.d2
                handles.b3 = handles.d3
                handles.b4 = handles.d4
                handles.b5 = handles.d5
                handles.b6 = handles.d6
                handles.b7 = handles.d7
                handles.b8 = handles.d8
                handles.Aw2 = handles.Aw3
                handles.gam2 = handles.gam3
                handles.b9 = handles.d9
                set(handles.t4,'String',handles.b1)
                set(handles.t5,'String',handles.d1)
                handles.d1 = ' '
                handles.d2 = 0
                handles.d3 = 0
                handles.d4 = 0
                handles.d5 = 0
                handles.d6 = 0
                handles.d7 = 0
                handles.d8 = 0
                handles.Aw3 = 0
                handles.gam3 = 0
                handles.d9 = 0
                set(handles.t6,'String',' ')
                handles.contador = handles.contador - 1
            else:
                if handles.b1 == 'Be':
                    handles.b1 = handles.d1
                    handles.b2 = handles.d2
                    handles.b3 = handles.d3
                    handles.b4 = handles.d4
                    handles.b5 = handles.d5
                    handles.b6 = handles.d6
                    handles.b7 = handles.d7
                    handles.b8 = handles.d8
                    handles.Aw2 = handles.Aw3
                    handles.gam2 = handles.gam3
                    handles.b9 = handles.d9
                    set(handles.t5,'String',handles.d1)
                    handles.d1 = ' '
                    handles.d2 = 0
                    handles.d3 = 0
                    handles.d4 = 0
                    handles.d5 = 0
                    handles.d6 = 0
                    handles.d7 = 0
                    handles.d8 = 0
                    handles.Aw3 = 0
                    handles.gam3 = 0
                    handles.d9 = 0
                    set(handles.t6,'String',' ')
                    handles.contador = handles.contador - 1
                else:
                    handles.d1 = ' '
                    handles.d2 = 0
                    handles.d3 = 0
                    handles.d4 = 0
                    handles.d5 = 0
                    handles.d6 = 0
                    handles.d7 = 0
                    handles.d8 = 0
                    handles.Aw3 = 0
                    handles.gam3 = 0
                    handles.d9 = 0
                    set(handles.t6,'String',' ')
                    handles.contador = handles.contador - 1
    
    handles
    guidata(hObject,handles)
    # --- Executes on button press in Na.
# Out:
#   File "<fstring>", line 1
#     (%d)
#      ^
# SyntaxError: invalid syntax
